# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import glob
import numpy as np
import plotly.plotly as py
import plotly.figure_factory as ff
from mpl_toolkits.basemap import Basemap
import folium
from folium.plugins import HeatMap
from folium import plugins
folium.plugins.HeatMap

# %matplotlib inline

# %%
filelist = glob.glob('./Resources/*.csv')
filelist

#for filename in glob.glob('./Resources/*.csv')
# Out:
# ['./Resources/April_2017.csv',
#  './Resources/August_2017.csv',
#  './Resources/December_2017.csv',
#  './Resources/February_2017.csv',
#  './Resources/January_2017.csv',
#  './Resources/July_2017.csv',
#  './Resources/June_2017.csv',
#  './Resources/March_2017.csv',
#  './Resources/May_2017.csv',
#  './Resources/November_2017.csv',
#  './Resources/October_2017.csv',
#  './Resources/September_2017.csv']

# %%
f = open(filelist[0])
columns = f.readline()
columns = columns.strip().split(',')
columns[0] = 'X'
f.close()

columns += ['MONTH', 'SEASON']

master_df = pd.DataFrame(columns = columns)

for filename in filelist:
    month_csv = pd.read_csv(filename)
    month_df = pd.DataFrame(month_csv)
    month_df['MONTH'] = filename.split('/')[1][:-9]
    if "April" in filename or "March" in filename or "May" in filename:
        month_df["SEASON"] = "Spring"
    elif "January" in filename or "February" in filename or "December" in filename:
        month_df["SEASON"] = "Winter"
    elif "June" in filename or "July" in filename or "August" in filename:
        month_df["SEASON"] = "Summer"
    elif "September" in filename or "October" in filename or "November" in filename:
        month_df["SEASON"] = "Fall"
    else:
        month_df["SEASON"] = "Oh no!"
        
    master_df = pd.concat([master_df, month_df], axis=0, sort=False)

# %%
master_df.count()
# Out:
# X                        1404052
# Y                        1404052
# OBJECTID                 1404052
# ROWID_                    174954
# DAY_OF_WEEK                    0
# HOLIDAY                        0
# WEEK_OF_YEAR                   0
# MONTH_OF_YEAR                  0
# ISSUE_TIME                     0
# VIOLATION_CODE           1404052
# VIOLATION_DESCRIPTION    1389544
# LOCATION                 1404052
# RP_PLATE_STATE           1393022
# BODY_STYLE                173700
# ADDRESS_ID               1404052
# STREETSEGID              1398855
# XCOORD                   1404052
# YCOORD                   1404052
# TICKET_ISSUE_DATE        1404052
# MONTH                    1404052
# SEASON                   1404052
# dtype: int64

# %%
master_df.head()
# Out:
#            X          Y OBJECTID  ROWID_  DAY_OF_WEEK  HOLIDAY  WEEK_OF_YEAR  \
# 0 -76.990896  38.892807  2750258     NaN          NaN      NaN           NaN
# 1 -76.980569  38.888851  2750259     NaN          NaN      NaN           NaN
# 2 -76.980569  38.888851  2750260     NaN          NaN      NaN           NaN
# 3 -76.979301  38.888518  2750261     NaN          NaN      NaN           NaN
# 4 -76.981491  38.888680  2750262     NaN          NaN      NaN           NaN
#
#    MONTH_OF_YEAR  ISSUE_TIME VIOLATION_CODE   ...    \
# 0            NaN         NaN           P050   ...
# 1            NaN         NaN           P002   ...
# 2            NaN         NaN           P170   ...
# 3            NaN         NaN           P303   ...
# 4            NaN         NaN           P003   ...
#
#                            LOCATION RP_PLATE_STATE BODY_STYLE ADDRESS_ID  \
# 0  1100 BLOCK PARK ST NE NORTH SIDE             VA        NaN     801357
# 1   SIDE OF 1700 A ST SE SOUTH SIDE             DC        NaN      57985
# 2   SIDE OF 1700 A ST SE SOUTH SIDE             DC        NaN      57985
# 3  FRONT OF 1753 A ST SE SOUTH SIDE             DC        NaN      56532
# 4     1700 BLOCK A ST SE NORTH SIDE             VA        NaN     802308
#
#   STREETSEGID  XCOORD  YCOORD         TICKET_ISSUE_DATE MONTH  SEASON
# 0      1321.0  400790  136106  2017-04-24T08:36:00.000Z        Spring
# 1     13169.0  401686  135667  2017-04-24T10:26:00.000Z        Spring
# 2     13169.0  401686  135667  2017-04-24T10:28:00.000Z        Spring
# 3     13169.0  401796  135630  2017-04-24T10:33:00.000Z        Spring
# 4      2993.0  401606  135648  2017-04-24T12:23:00.000Z        Spring
#
# [5 rows x 21 columns]

# %%
master_df = master_df.drop(["ROWID_", "DAY_OF_WEEK", "HOLIDAY", "WEEK_OF_YEAR", "MONTH_OF_YEAR", "ISSUE_TIME", "BODY_STYLE"], axis = 1)
master_df.head()
# Out:
#            X          Y OBJECTID VIOLATION_CODE  \
# 0 -76.990896  38.892807  2750258           P050
# 1 -76.980569  38.888851  2750259           P002
# 2 -76.980569  38.888851  2750260           P170
# 3 -76.979301  38.888518  2750261           P303
# 4 -76.981491  38.888680  2750262           P003
#
#                                VIOLATION_DESCRIPTION  \
# 0               PARKED WITHIN 25 FEET OF A STOP SIGN
# 1                             STAND OR PARK IN ALLEY
# 2                    FAILURE TO DISPLAY CURRENT TAGS
# 3  RESERVED RESIDENTIAL SPACE PERSONS W/ DISABILTIES
# 4   RESIDENTIAL PERMIT PKING BEYOND LIMIT W/O PERMIT
#
#                            LOCATION RP_PLATE_STATE ADDRESS_ID  STREETSEGID  \
# 0  1100 BLOCK PARK ST NE NORTH SIDE             VA     801357       1321.0
# 1   SIDE OF 1700 A ST SE SOUTH SIDE             DC      57985      13169.0
# 2   SIDE OF 1700 A ST SE SOUTH SIDE             DC      57985      13169.0
# 3  FRONT OF 1753 A ST SE SOUTH SIDE             DC      56532      13169.0
# 4     1700 BLOCK A ST SE NORTH SIDE             VA     802308       2993.0
#
#    XCOORD  YCOORD         TICKET_ISSUE_DATE MONTH  SEASON
# 0  400790  136106  2017-04-24T08:36:00.000Z        Spring
# 1  401686  135667  2017-04-24T10:26:00.000Z        Spring
# 2  401686  135667  2017-04-24T10:28:00.000Z        Spring
# 3  401796  135630  2017-04-24T10:33:00.000Z        Spring
# 4  401606  135648  2017-04-24T12:23:00.000Z        Spring

# %%
with pd.option_context("display.max_rows", 1000):
   print(master_df["VIOLATION_DESCRIPTION"].value_counts())
# Out:
# FAIL TO DISPLAY A MULTISPACE METER RECEIPT            161265
# PARK AT EXPIRED METER                                 144967
# DISOBEYING OFFICIAL SIGN                               97544
# RESIDENTIAL PERMIT PKING BEYOND LIMIT W/O PERMIT       96849
# NO PARKING STREET CLEANING                             85162
# NO STOPPING OR STANDING IN PM RUSH HOUR ZONE           67802
# FAILURE TO DISPLAY CURRENT TAGS                        67126
# NO PARKING ANYTIME                                     52995
# UNAUTHORIZED VEHICLE IN LOADING ZONE                   42734
# FAILURE TO SECURE DC TAGS                              42728
# NO STANDING ANYTIME                                    37537
# PARK OVERTIME AT A METER                               34460
# NO STOPPING OR STANDING IN AM RUSH HOUR ZONE           32328
# NO FRONT TAGS.                                         28991
# PARKED WITHIN 25 FEET OF A STOP SIGN                   25514
# EXPIRATION TIME ON METER RECEIPT LAPSED                23811
# STAND OR PARK IN ALLEY                                 22323
# PARK WITHIN 5 FEET OF DRIVEWAY OR ALLEY                21082
# RELOCATE TOW FEE                                       20879
# PARK OVERTIME IN TIMED ZONE                            20304
# PARK IN A BUS ZONE                                     19642
# VEHICLE ON PRIVATE/PUBLIC PROPERTY WITHOUT CONSENT     16759
# FAIL TO DISPLAY CURRENT INSPECTION STICKER             16590
# RESIDENTIAL PMT PKG 3RD OFFENSE CALENDAR YEAR          15667
# FAIL TO REPORT FOR INSPECTION.                         14169
# PARK WITHIN 10 FEET OF A FIRE HYDRANT                  13518
# RESIDENTIAL PMT PKG 2ND OFFENSE CALENDAR YEAR          12650
# EMERGENCY NO PARKING                                   11885
# PARK IN A DESIGNATED ENTRANCE                          10407
# NO PARKING SPECIFIC HOURS                               9802
# METER, FAIL TO DEPOSIT PAYMENT                          9596
# PARK ABREAST OF ANOTHER VEHICLE                         9422
# INDIVID W/ DISABILITIES ONLY UNAUTH. USE RSRVD SP       6880
# NO STOPPING ANYTIME                                     6545
# PARK IN OFFICIAL PARKING PERMIT ONLY SPACE              6331
# NO REAR TAGS.                                           5974
# NO STOPPING OR STANDING ANYTIME                         4897
# OBSTRUCTING CROSSWALK                                   4594
# NOT PARKED IN A METER SPACE                             4567
# PARK ON PUBLIC SPACE                                    4424
# STOPPING, STANDING OR PARKING VEHICLE IN BIKE LANE      3941
# PARK LESS THAN 40 FEET FROM AN INTERSECTION             3873
# PARK LESS THAN 25 FEET FROM AN INTERSECTION             3811
# IND. W/ DISABILITIES METER  NO PROOF OF PAYMENT         3305
# PARK IN SCHOOL ZONE                                     3295
# PARK WITH LEFT WHEEL TO THE CURB                        2582
# FAIL TO PROPERLY AFFIX VALIDATION STICKERS              2363
# EXPIRED INSPECTION REJECTION STICKER                    2269
# PARK IN RESERVED SPACE FOR MOTORCYCLES ONLY             2129
# RESERVED RESIDENTIAL SPACE PERSONS W/ DISABILTIES       2072
# PARKED ON DESIGNATED VENDOR AREA                        2052
# GOVERNMENT VEHICLE PARKING ONLY                         1538
# PARK IN RESERVED EMBASSY SPACE                          1465
# FAIL TO DISPLAY MULTI SPACE RECEIPT  BALLPARKEVENT      1419
# PARK ON SIDEWALK OR AREA RESERVED FOR PEDESTRIANS       1368
# NO PARKING 7 AM TO 6:30 PM                              1355
# PARKED IN DRIVEWAY OR ALLEY TO OBSTRUCT SIDEWALK        1198
# PARK ON TAXICAB STAND                                   1168
# PARK IN MEDIAN, ISLAND, OR SAFETY ZONE                  1132
# PARK MORE THAN 12 INCHES FROM CURB                      1047
# PARK IN A FIRE LANE                                      846
# FAIL TO DISPLAY METER RECEIPT IN A LOADING ZONE          838
# ABANDON VEHICLE ON PUBLIC/PRIVATE PROPERTY VIOL 1        803
# OPP OR BESIDE CONTRUCTION SITE OBSTRUCTING TRAFFIC       750
# OBSTRUCTING ENTRANCE OF PKG GARAGE, DOOR OR GATE         621
# EXPIRED HANDICAP METER                                   596
# IMPROPER DISPLAY OF TAGS                                 591
# STREETCAR-PARK, STOP  STAND VEH  GUIDEWAY/PLATFORM       569
# COMMERCIAL MOTOR VEHICLE - NOT OUT OF SERVICE            532
# NON-TAXI ON HACK STAND                                   518
# VALET PARKING/STAGING ZONE                               488
# FAIL TO DISPLAY MULTI-SPACE METER RECEIPT PROPERLY       460
# DANGEROUS VEHICLE ON PRIV/PUBLIC PROP VIOL 1             409
# RPP BEYOND 2 HOUR PERIOD W/O VALID PERMIT BZ             401
# PARK ON OR UNDER AN ELEVATED STRUCTURE                   401
# FAIL TO DISPLAY MULTI-SPACE PARKING METER RCPT BZ        376
# PARKED IN A RESERVED CAR SHARING SPACE                   361
# PARK WITHIN 20 FEET OF A BUS STOP OR ZONE                355
# OVERSIZED COMM VEHICLE PARKED AT A METER                 351
# MOTOR RUNNING UNATTENDED                                 346
# FAIL TO PARK PARALLEL                                    320
# COMMERCIAL MOTOR VEHICLE - OUT OF SERVICE                311
# PARK VEHICLE IN FRONT OF A BARRICADE                     274
# IND. W/ DISABILITIES AMOUNT OF PAYMENT HAS LAPSED        269
# PARK ON MEDIAN, ISLAND, OR SAFETY ZONE                   232
# TAXICAB LOITERING.                                       231
# PARK TO REDUCE ROADWAY TO LESS THAN 10 FEET              225
# OVERTIME AT A MULTISPACE METER IN A LOADING ZONE         180
# OBSTRUCTED TAGS.                                         145
# OBSTRUCT AN INTERSECTION                                 139
# FAIL TO DISPLAY CURRENT DC VEHICLE TAGS                  113
# NO STANDING COMMERCIAL VEHICLE                           111
# STREETCAR-PARK, STOP STAND VEH GUIDEWAY/PLATFORM         108
# VEHICLE > 22'  PUBLIC ST FRT DWELLING,SCHOOL, HOSP       105
# PARK IN AN UNDESIGNATED SPACE                            100
# PARK ON SIGHTSEEING STAND                                 82
# RPP BALLPARK ZONE 3RD OFFENSE CALENDAR YEAR               78
# FAIL TO REGISTER APPORTIONABLE VEHICLE UNDER IRP          77
# EXCESSIVE IDLING.                                         69
# RESIDENTIAL PMT PKG  BALLPARK ZONE 2ND OFF CAL YR         67
# PARK BETWEEN ISLAND OR SAFETY ZONE                        60
# IND. W/ DISABILITIES PARKED BEYOND TIME LIMIT             59
# NO PARKING EXC. ELECTRIC VEHICLE BEING CHARGED            58
# PARKED LESS THAN 3 FEET FROM ANOTHER VEHICLE              51
# BUS LANE, UNAUTHORIZED VEHICLE PARKED IN                  51
# TINTED WINDOWS                                            49
# PARK IN RESERVED SPACE                                    41
# UNAUTHORIZED  USE IND. W/ DISABILITIES PARK PRIV          41
# FAIL TO DISPLAY RESIDENTIAL PARKING PERMIT                40
# PARK WITHIN 20 FEET OF A FIREHOUSE ENTRANCE               38
# PARK FOR PURPOSE OF VEHICLE SALE OR REPAIR                36
# DRIVER MORE THAN FIVE FEET FROM TAXI                      36
# ABANDON VEHICLE ON PUBLIC/PRIVATE PROPERTY VIOL 3         36
# COMM VEH MORE THAN 22 FEET IN FRONT OF RESIDENCE          35
# PERMIT UNLICENSED HACKER                                  34
# PARK ON PRIVATE OR PUBLIC PROPERTY                        33
# METER BALL PARK EVENT, DEPOSIT ADDITONAL PAYMENT          29
# EXPIRED MULTISPACE METER RECEIPT IN LOADING ZONE          28
# FAIL TO TURN WHEEL TO CURB.                               28
# FAILURE TO DISPLAY MULI-SPACE RECEIPT PROPERLY BZ         27
# FAIL TO LOCK AND REMOVE KEY FROM IGNITION WHEN PKD        26
# FAIL TO REMOVE EXPIRED RESIDENTIAL PARKING PERMIT         26
# MOTOR CARRIER DRIVER VIOLATION OUT OF SERVICE             24
# TAXICAB PARKED OFF TAXI STAND                             24
# PARK WITHIN TWENTY FIVE FEET FROM A YIELD SIGN            22
# VEH > 8' WIDE PUBLIC ST, FRT DWELLING, SCHOOL,HOSP        22
# PARK IN AN UNLIGHTED AREA (PARKING AREA)                  21
# EXPIRATION TIME ON METER RECEIPT LAPSED BE                20
# RPP BEYOND 2 HOUR PERIOD W/O VALID PERMIT BE              20
# NOT PARKED IN PARKING METER SPACE BZ                      20
# VEH >15 PASS, PUBLIC ST FRT DWELLING, SCH, HOSP,          20
# ILLEGIBLE TAGS.                                           19
# PARK ON A LAWN                                            19
# PARKING ON SNOW EMERGENCY ROUTE WHEN PROHIBITED           19
# FAIL TO SECURE TAGS IN THE DISTRICT OF COLUMBIA           18
# VEHICLE HAUL TRASH, DEBRIS OR JUNK                        17
# TRAILER, FRT DWELLING, SCHOOL, HOSPITAL                   16
# FAIL DISPLAY MULTI SPACE RECEIPT PROPERLY BE              16
# UNSAFE TIRES                                              16
# METER BALL PARK EVENT, FAIL TO DEPOSIT PAYMENT            15
# MOTOR CARRIER VEHICLE VIOLATION OUT OF SERVICE            15
# ABANDON VEHICLE ON PUBLIC/PRIVATE PROPERTY VIOL 2         15
# IMPROPERLY DISPLAYED TAGS                                 14
# TAXICAB PARKED 100 FEET FROM STAND                        13
# EXCEED GROSS WEIGHT INDICATED ON IRP REGISTRATION         13
# VEHICLE > 22 PUBLIC ST FRT DWELLING,SCHOOL, HOSP          12
# PARK IN BUS STOP OR ZONE DURING RUSH HOUR                 12
# PARK AT CURB IN LOADING ZONE                              11
# FAIL TO OBTAIN IRP TRIP PERMIT                            10
# FAIL TO SET EMERGENCY BRAKE                               10
# TAXICAB FAIL TO PULL TO CURB                               9
# OVERSIZED VEHICLE AT METER BALL PARK EVENT                 9
# VENDING USING IND. W/ DISABILITIES PARK PRIVILEGES         9
# ABANDON VEH PRIV/PUBLIC PROP SOLID WASTE/RAT               8
# ONE RUNNING HEAD LIGHT                                     8
# DEPOSIT PAYMENT TO EXTEND TIME BEYOND METER LIMIT          8
# OBSTRUCTING FIRE ESCAPE                                    8
# OVERTIME BALL PARK EVENT                                   7
# PARK WITHIN 25 FEET OF A MAILBOX                           7
# ILLEGAL AT METER BALL PARK EVENT                           7
# DANGEROUS VEH ON PRIV/PUBLIC PROP S/W VIOL 1               7
# MAKING NON EMERGENCY REPAIRS ON ROADWAY                    6
# NOT PARKED IN PARKING METER SPACE  BE                      6
# PARK TOO CLOSE APPROACHING INTERSECTION                    5
# UNSAFE MECHANICAL CONDITION                                5
# NO SIGNAL DEVICE                                           5
# COMMERCIAL PMT PARK DECAL, FAIL DISPLAY PROPERLY           5
# EXPIRATION TIME ON METER RECEIPT LAPSED BZ                 5
# VEH > 8 WIDE PUBLIC ST, FRT DWELLING, SCHOOL,HOSP          4
# IMPROPERLY USING A TAXICAB OR LIMOUSINE STAND (PRI         4
# TAXICAB FAIL TO EXHIBIT LICENSE                            4
# FORGED VISITOR PARKING PLACARD                             4
# LIMOUSINE PARKED ON HACK STAND                             4
# TAXICAB IMPROPER USE OF ON CALL SIGN                       4
# TINTED WINDOWS , FAIL TO COMPLY 1ST                        4
# RESIDENTIAL PMT PKG BALLPARK ZONE 2ND OFF CAL YR           4
# RESIDENTIAL PMT PKG  3RD  OFFENSE BALLPARK EVENT           3
# RPP FAIL TO PROPERLY DISPLAY CURRENT STICKER  BZ           3
# SPILLED LOAD FROM COMMERCIAL VEHICLE                       3
# RPP FAIL TO REMOVE EXPIRED STICKER BALLPARK EVENTS         3
# OVERTIME PARKING IN A LOADING ZONE METER SPACE             3
# PARK MORE THAN 72 HOURS                                    3
# TRUCK IN PUBLIC PARK AREA                                  3
# FAIL TO DISPLAY RECIPROCITY STICKER                        3
# FORGED TEMPORARY PARKING PLACARD                           3
# USE OF IMPROPER LIGHTS                                     3
# LOADS NOT SECURED                                          3
# TAXICAB SOLICITING FARE                                    3
# USE OF HIGH BEAM LIGHTS                                    2
# DANGEROUS VEHICLE ON PRIV/PUBLIC PROP VIOL 3               2
# RPP FAIL TO REMOVE EXPIRED STICKER BALL PARK ZONE          2
# OVERTIME AT METER BZ                                       2
# TINTED WINDOWS  FAIL TO COMPLY 2ND                         2
# ILLEGAL AT METER                                           2
# TAXICAB FAIL TO DISPLAY RATE CARD                          2
# FAIL TO PROPERLY DISPLAY  MULTISPACE METER RECEIPT         2
# OVERTIME AT METER BALLPARK EVENT                           2
# FORGED/COUNTERFEIT  VISITOR PARKING PERMIT                 2
# TAXICAB DISPLAYING IMPROPER INSIGNIA                       2
# OVERSIZED VEHICLE AT METER BZ                              2
# DANGEROUS VEH ON PRIV/PUBLIC PROP S/W VIOL 3               2
# COMMERCIAL PERMIT PARKING DECAL, DISPLAY EXPIRED           2
# CMV- NON LOAD ZONE  METER SPACE PROHIBITED  TIMES          2
# DANGEROUS VEHICLE ON PRIV/PUBLIC PROP VIOL 2               2
# TAXICAB LOADING PASSENGERS IN A CROSSWALK                  2
# TAXICAB FAIL TO SHOW ID                                    1
# NO OR DISCONNECTED MUFFLER                                 1
# PROVIDE FALSE INFO TO OBTAIN VISITOR PARKING PERM          1
# DRIVE TRUCK ON RESTRICTED ROUTE                            1
# TAXICAB NOT USING OFF DUTY SIGN                            1
# NO RED FLAG ON THE END OF A LOAD                           1
# FAIL TO PROPERLY DISPLAY INSPECTION STICKER SIGN           1
# UNNECESSARY NOISE.                                         1
# TAXICAB FAIL TO UPDATE CHANGE OF ADDRESS                   1
# PARK IN A CURB LOADING ZONE                                1
# EXCESSIVE SMOKE.                                           1
# PROVIDE FALSE INFORMATION TO OBTAIN RPP PERMIT             1
# NO SNOW TIRES OR CHAINS                                    1
# INCORRECT BUMPER ON A VENDING VEHICLE                      1
# NO STOP LIGHTS                                             1
# TORN FENDERS                                               1
# VEHICLE ON PRIVATE/PUBLIC PROP W/O CONSENT 3D OFF          1
# GLASS LEFT IN THE STREET                                   1
# LOAD EXTENDS OVER FENDER                                   1
# DEFECTIVE SPEEDOMETER.                                     1
# TAXICAB CRUISING LIGHTS                                    1
# DISPLAY METER RECEIPT FROM MTR OUTSIDE AREA BE             1
# RESERVED SPACE NO PARKING                                  1
# METER ADD'L PAYMENT TO EXTEND TIME BEYOND LIMIT BZ         1
# TAXICAB NO MANIFEST                                        1
# MOVING A LOAD OVER EIGHT FEET WIDE                         1
# RPP BALLPARK EVENTS 2ND OFFENSE CALENDAR YEAR              1
# NO REAR VIEW MIRROR                                        1
# PARK IN A GUTTER                                           1
# NO REAR LIGHTS.                                            1
# PROVIDE FALSE INFO TO OBTAIN TEMP PARKING PLACARD          1
# PARKING MISC                                               1
# MOTOR CARRIER HAZMAT VIOLATION OUT OF SERVICE              1
# Name: VIOLATION_DESCRIPTION, dtype: int64

# %%
len(master_df["VIOLATION_CODE"].value_counts())
# Out:
# 243

# %%
len(master_df["VIOLATION_DESCRIPTION"].value_counts())
# Out:
# 238

# %%
with pd.option_context("display.max_rows", 1000):
   print(master_df["VIOLATION_CODE"].value_counts())
# Out:
# P281       161265
# P039       144967
# P012        97544
# P003        96849
# P173        85162
# P259        67802
# P170        67126
# P055        52995
# P031        42734
# P172        42728
# P269        37537
# P037        34460
# P159        32328
# P168        28991
# P050        25514
# P280        23811
# P002        22323
# P013        21082
# P386        20879
# P322        20304
# P007        19642
# P344        16759
# P113        16590
# P365        15667
# P076        14250
# P112        14169
# P020        13518
# P363        12650
# P014        11885
# P199        10407
# P057         9802
# P034         9596
# P001         9422
# P304         6880
# P271         6545
# P036         6331
# P169         5974
# P270         4897
# P010         4594
# P035         4567
# P042         4424
# P385         3941
# P025         3873
# P024         3811
# P430         3305
# P046         3295
# P029         2582
# P314         2363
# P111         2269
# P307         2129
# P303         2072
# P054         2052
# P302         1538
# P045         1465
# P216         1419
# P047         1368
# P056         1355
# P320         1198
# P022         1168
# P318         1132
# P011         1047
# P059          846
# P285          838
# P332          803
# P016          750
# P418          626
# P015          621
# P239          596
# P316          591
# P361          532
# P417          518
# P346          488
# P278          460
# P338          409
# P396          401
# P005          401
# P366          376
# P282          361
# P198          355
# P032          351
# P077          346
# P040          320
# P360          311
# P004          274
# P431          269
# NO VIOL       251
# P306          232
# P120          231
# P043          225
# P287          180
# P093          145
# P023          139
# P410          117
# P104          113
# P058          111
# P027          100
# P048           82
# P369           78
# P190           77
# P367           71
# P017           69
# P311           60
# P432           59
# P403           58
# P419           51
# P053           51
# P429           51
# P331           49
# P044           41
# P434           41
# P309           40
# P019           38
# P122           36
# P063           36
# P334           36
# P051           35
# P330           34
# P041           33
# P213           29
# P284           28
# P300           28
# P370           27
# P072           26
# P310           26
# P411           26
# P123           24
# P326           24
# P312           22
# P028           21
# P373           20
# P407           20
# P395           20
# P409           20
# P026           19
# P315           19
# P161           19
# P250           18
# P412           17
# P158           16
# P413           16
# P371           16
# P215           15
# P327           15
# P333           15
# P090           14
# P192           13
# P210           13
# P319           12
# P301           11
# P191           10
# P321           10
# P127            9
# P433            9
# P217            9
# P150            8
# P033            8
# P018            8
# P218            7
# P341            7
# P214            7
# P305            7
# P194            6
# P335            6
# P387            6
# P157            6
# P421            5
# P406            5
# P109            5
# P200            5
# P030            5
# P135            4
# P205            4
# P901            4
# P416            4
# P404            4
# P151            3
# P070            3
# P147            3
# P038            3
# P313            3
# P279            3
# P187            3
# P401            3
# P408            3
# P193            3
# P052            3
# P400            3
# P125            3
# P392            2
# P393            2
# P289            2
# P420            2
# P339            2
# P343            2
# P424            2
# P390            2
# P399            2
# P206            2
# P204            2
# P340            2
# P288            2
# P146            2
# P209            2
# P405            2
# P085            1
# P107            1
# P153            1
# P376            1
# P067            1
# P149            1
# P189            1
# P195            1
# P095            1
# P133            1
# P00             1
# P276            1
# P110            1
# P262            1
# P201            1
# P336            1
# P176            1
# P148            1
# P328            1
# P345            1
# P118            1
# P100            1
# P374            1
# P117            1
# P140            1
# P101            1
# P196            1
# P415            1
# P675            1
# P021            1
# P154            1
# P391            1
# P197            1
# P362            1
# P152            1
# P097            1
# P121            1
# P178            1
# P337            1
# Name: VIOLATION_CODE, dtype: int64

# %%
map_df = master_df[['X', 'Y']].copy()
map_df.head()
# Out:
#            X          Y
# 0 -76.990896  38.892807
# 1 -76.980569  38.888851
# 2 -76.980569  38.888851
# 3 -76.979301  38.888518
# 4 -76.981491  38.888680

# %%
map_df.count()
# Out:
# X    1404052
# Y    1404052
# dtype: int64

# %%
Map = folium.Map([38.9072, -77.0369], zoom_start=13)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for index, row in map_df.iterrows():
    folium.CircleMarker([row['X'], row['Y']],
                        radius=15,
                        fill_color="#3db7e4",
                       ).add_to(Map)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-054cf0dba082> in <module>()
#       2     folium.CircleMarker([row['X'], row['Y']],
#       3                         radius=15,
# ----> 4                         fill_color="#3db7e4",
#       5                        ).add_to(Map)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/folium/features.py in __init__(self, location, radius, popup, **kw)
#     882                 ).addTo({{this._parent.get_name()}});
#     883             {% endmacro %}
# --> 884             """)
#     885
#     886
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/jinja2/environment.py in __new__(cls, source, block_start_string, block_end_string, variable_start_string, variable_end_string, comment_start_string, comment_end_string, line_statement_prefix, line_comment_prefix, trim_blocks, lstrip_blocks, newline_sequence, keep_trailing_newline, extensions, optimized, undefined, finalize, autoescape, enable_async)
#     943             frozenset(extensions), optimized, undefined, finalize, autoescape,
#     944             None, 0, False, None, enable_async)
# --> 945         return env.from_string(source, template_class=cls)
#     946
#     947     @classmethod
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/jinja2/environment.py in from_string(self, source, globals, template_class)
#     878         globals = self.make_globals(globals)
#     879         cls = template_class or self.template_class
# --> 880         return cls.from_code(self, self.compile(source), globals, None)
#     881
#     882     def make_globals(self, d):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/jinja2/environment.py in compile(self, source, name, filename, raw, defer_init)
#     577             if isinstance(source, string_types):
#     578                 source_hint = source
# --> 579                 source = self._parse(source, name, filename)
#     580             source = self._generate(source, name, filename,
#     581                                     defer_init=defer_init)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/jinja2/environment.py in _parse(self, source, name, filename)
#     495     def _parse(self, source, name, filename):
#     496         """Internal parsing function used by `parse` and `compile`."""
# --> 497         return Parser(self, source, name, encode_filename(filename)).parse()
#     498
#     499     def lex(self, source, name=None, filename=None):
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/jinja2/parser.py in parse(self)
#     899     def parse(self):
#     900         """Parse the whole template into a `Template` node."""
# --> 901         result = nodes.Template(self.subparse(), lineno=1)
#     902         result.set_environment(self.environment)
#     903         return result
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/jinja2/parser.py in subparse(self, end_tokens)
#     881                        self.stream.current.test_any(*end_tokens):
#     882                         return body
# --> 883                     rv = self.parse_statement()
#     884                     if isinstance(rv, list):
#     885                         body.extend(rv)
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/jinja2/parser.py in parse_statement(self)
#     128         try:
#     129             if token.value in _statement_keywords:
# --> 130                 return getattr(self, 'parse_' + self.stream.current.value)()
#     131             if token.value == 'call':
#     132                 return self.parse_call_block()
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/jinja2/parser.py in parse_macro(self)
#     382         self.parse_signature(node)
#     383         node.body = self.parse_statements(('name:endmacro',),
# --> 384                                           drop_needle=True)
#     385         return node
#     386
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/jinja2/parser.py in parse_statements(self, end_tokens, drop_needle)
#     162         # in the future it would be possible to add whole code sections
#     163         # by adding some sort of end of statement token and parsing those here.
# --> 164         self.stream.expect('block_end')
#     165         result = self.subparse(end_tokens)
#     166
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/jinja2/lexer.py in expect(self, expr)
#     386             return self.current
#     387         finally:
# --> 388             next(self)
#     389
#     390
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/jinja2/lexer.py in __next__(self)
#     357         elif self.current.type is not TOKEN_EOF:
#     358             try:
# --> 359                 self.current = next(self._iter)
#     360             except StopIteration:
#     361                 self.close()
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/jinja2/lexer.py in wrap(self, stream, name, filename)
#     560         every token in a :class:`Token` and converts the value.
#     561         """
# --> 562         for lineno, token, value in stream:
#     563             if token in ignored_tokens:
#     564                 continue
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/jinja2/lexer.py in tokeniter(self, source, name, filename, state)
#     625             # tokenizer loop
#     626             for regex, tokens, new_state in statetokens:
# --> 627                 m = regex.match(source, pos)
#     628                 # if no match we try again with the next rule
#     629                 if m is None:
#
# KeyboardInterrupt:

# %%
#THIS IS THE SUBSET TEST DATA
maptest_df = map_df.drop_duplicates()
maptest_df.count()
# Out:
# X    26723
# Y    26723
# dtype: int64

# %% [markdown]
# Had I had more weeks to dig into this data, I would have been interested to see how DC's ticketing rate stacks up against the rest of the country.
# I would have liked to also dig into the revenue aspect of ticketing, and see if removing street parking as proposed would significantly impact DC's revenue.

# %%
m = folium.Map([38.9072, -77.0369], zoom_start=13)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapdf = pd.read_csv("testmap.csv")
mapdf.head()
# Out:
#    Unnamed: 0          X          Y
# 0           0 -76.990896  38.892807
# 1           1 -76.980569  38.888851
# 2           3 -76.979301  38.888518
# 3           4 -76.981491  38.888680
# 4           5 -76.978125  38.888679

# %%
# mark each station as a point
for index, row in mapdf.iterrows():
    folium.CircleMarker([row['X'], row['Y']],
                        radius=1,
                        fill_color="#FFC0CB", # divvy color
                       ).add_to(m)

# %%
# convert to (n, 2) nd-array format for heatmap

maptest_df["X"] = pd.to_numeric(maptest_df["X"])
maptest_df["Y"] = pd.to_numeric(maptest_df["Y"])

ticketlocs = maptest_df[['Y', 'X']].values.tolist()

ticketlocs

# plot heatmap
#m.add_child(plugins.HeatMap([[38.2222,-18.2222],[22,2233],[3322,11]], radius=15))

m.add_child(plugins.HeatMap(ticketlocs, radius=3))


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
some challenges faced: got far along with Folium, then learned they have a 66k plotting limit. had to proportionally downsize the dataset by Address ID so that the volume of tickets by area remained hte same, despite hte overall volume of tickets in DC potentailly taking a hit.
